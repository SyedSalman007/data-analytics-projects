# %% [markdown]
# # Project 02: E-Commerce Sales Dataset
#
# This notebook analyzes multi-channel e-commerce sales, pricing snapshots, inventory, expenses, and a warehouse profitability comparison (Shiprocket vs INCREFF).
#
# Outputs are written into `notebooks/02_ecommerce_sales/output/`.

# %%
from pathlib import Path
from ecommerce_sales_analysis import run_pipeline

BASE_DIR = Path('..').resolve()
result = run_pipeline(BASE_DIR)
result

# %% [markdown]
# ## Key Outputs
#
# - `sales_facts_combined.csv`
# - `monthly_trends.csv`, `monthly_revenue_trend.png`, `monthly_units_trend.png`
# - `amazon_category_mix.csv`, `amazon_top_categories_revenue.png`
# - `amazon_status_fulfilment_breakdown.csv` + per-field charts
# - `profitability_comparison_summary.csv`, `profitability_shiprocket_vs_increff.png`
# - `pricing_snapshot_summary.csv`, `pricing_channel_best_mrp_counts.csv`, pricing charts
# - `inventory_turnover_90d.csv`, `inventory_vs_units_90d.png`
# - `expenses_clean.csv`
# - `pipeline_summary.json`
