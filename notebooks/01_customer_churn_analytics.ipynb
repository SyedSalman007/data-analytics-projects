# %% [markdown]
# # Project 01: Customer Churn Analytics
#
# This notebook runs cohort retention analysis, pre-churn behavior analysis, churn risk segmentation, and churn model training.

# %%
from pathlib import Path
from customer_churn_analysis import run_pipeline

BASE_DIR = Path('..').resolve()
result = run_pipeline(BASE_DIR)
result

# %% [markdown]
# ## Output Files
#
# Generated outputs are saved to `notebooks/output/`, including:
# - `cohort_retention_heatmap.png`
# - `cohort_retention_table.csv`
# - `prechurn_behavior_patterns.png`
# - `prechurn_behavior_summary.csv`
# - `churn_risk_segments.csv`
# - `risk_segment_counts.png`
# - `churn_model_metrics.json`
# - `model_feature_importance.csv`
# - `model_feature_importance.png`
# - `pipeline_summary.json`
